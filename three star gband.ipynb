# %%
#import or connect to function libraries
import math as m
import numpy as np
import pandas as pd
from astropy.io import fits
import matplotlib.pyplot as plt
import time
# %matplotlib inline

# %%
#opening a fits file
datafile = fits.open('gaiadr2_100pc.fits')

# %%
#inspect secondary header
sechdr = datafile[1]
sechdr.header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                  697 / width of table in bytes
# NAXIS2  =               700055 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                   96 / number of columns
# EXTNAME = 'result  '           / table name
# TTYPE1  = 'solution_id'        / label for column 1
# TFORM1  = 'K       '           / format for column 1
# TCOMM1  = 'Solution Identifier'
# TUCD1   = 'meta.version'
# TTYPE2  = 'designation'        / label for column 2
# TFORM2  = '28A     '           / format for column 2
# TCOMM2  = 'Unique source designation (unique across all Data Releases)'
# TUCD2   = 'meta.id;meta.main'
# TTYPE3  = 'source_id'          / label for column 3
# TFORM3  = 'K       '           / format for column 3
# ...

# %%
ra = sechdr.data['ra']
dec = sechdr.data['dec']
gband = sechdr.data['phot_g_mean_mag']
parallex = sechdr.data['parallax']
p_error = sechdr.data['parallax_error']
n = len(sechdr.data['dec'])

# %%
with open('1simgadup_sort2.txt', 'r') as file:
    with open('threestar_gband17.txt', 'w') as f:
        for i in file.readlines():
            line = i.split(':')
            first = int(line[0])
            pre = line[1]
            line1 = pre.split(' ')
            second = int(line1[1])
            third = int(line1[2])
            if (gband[first]> 17 and gband[second]> 17 and gband[third]> 17):
                f.write(str(first) + "," + str(second) + "," + str(third) + "\n")
